# %%
# y = ax + b 
#find the best value of a , b
# Two class ---> Binary Regression

# %%
# Log-Loss ---> To find the loss function , scwah to change it into probabilty
# If the Log-loss is reach to 0 -> that mean the model is optimal , Acu , better
# If the Log-loss is high -> that mean the model is learning the probabilty will became less
# If the y and pi is together that mean the log-loss is 0
# Converg --> mean that going to each there [there is a problem] , moving toward 
# diverge --> mean that they are going fear away
# if the y hat and y to gether than the loss perfect 
# If the y hat

# %%
# Gradient Descent ---> small value

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
url = "https://rb.gy/9wttb"
names = ['preg','plas','skin','test','mass','pedi','age','class']
data = pd.read_csv(url,names=names)

# %%
# To see the table:
data
# Out:
#     preg  plas  skin  test  mass   pedi  age  class
# 6    148    72    35     0  33.6  0.627   50      1
# 1     85    66    29     0  26.6  0.351   31      0
# 8    183    64     0     0  23.3  0.672   32      1
# 1     89    66    23    94  28.1  0.167   21      0
# 0    137    40    35   168  43.1  2.288   33      1
# ..   ...   ...   ...   ...   ...    ...  ...    ...
# 10   101    76    48   180  32.9  0.171   63      0
# 2    122    70    27     0  36.8  0.340   27      0
# 5    121    72    23   112  26.2  0.245   30      0
# 1    126    60     0     0  30.1  0.349   47      1
# 1     93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 8 columns]

# %%
# Print them and see the details:
print(data.head())
print(data.describe())
print(data.info())
# Out:
#    preg  plas  skin  test  mass   pedi  age  class
# 6   148    72    35     0  33.6  0.627   50      1
# 1    85    66    29     0  26.6  0.351   31      0
# 8   183    64     0     0  23.3  0.672   32      1
# 1    89    66    23    94  28.1  0.167   21      0
# 0   137    40    35   168  43.1  2.288   33      1
#              preg        plas        skin        test        mass        pedi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean   120.894531   69.105469   20.536458   79.799479   31.992578    0.471876
# std     31.972618   19.355807   15.952218  115.244002    7.884160    0.331329
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.078000
# 25%     99.000000   62.000000    0.000000    0.000000   27.300000    0.243750
# 50%    117.000000   72.000000   23.000000   30.500000   32.000000    0.372500
# 75%    140.250000   80.000000   32.000000  127.250000   36.600000    0.626250
# ...

# %%
sns.pairplot(data,hue='class')
plt.show()

# %%
# Split the Features(x) and the Target (y):
# By using iloc :
# Features :
# Make it parmently:
x=data.iloc[:,:-1]
x
# Out:
#     preg  plas  skin  test  mass   pedi  age
# 6    148    72    35     0  33.6  0.627   50
# 1     85    66    29     0  26.6  0.351   31
# 8    183    64     0     0  23.3  0.672   32
# 1     89    66    23    94  28.1  0.167   21
# 0    137    40    35   168  43.1  2.288   33
# ..   ...   ...   ...   ...   ...    ...  ...
# 10   101    76    48   180  32.9  0.171   63
# 2    122    70    27     0  36.8  0.340   27
# 5    121    72    23   112  26.2  0.245   30
# 1    126    60     0     0  30.1  0.349   47
# 1     93    70    31     0  30.4  0.315   23
#
# [768 rows x 7 columns]

# %%
# Target :
# Make it parmently:
y=data.iloc[:,-1]
y
# Out:
# 6     1
# 1     0
# 8     1
# 1     0
# 0     1
#      ..
# 10    0
# 2     0
# 5     0
# 1     1
# 1     0
# Name: class, Length: 768, dtype: int64

# %%
# OR :
X = data.drop('class',axis=1)
Y = data['class']

# %%
# Tarin and Test the data :
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# Create a Logistic Regression object and train it using the training data :
lr = LogisticRegression(max_iter=400)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=400)

# %%
# Make predictions using test set:
y_pred = lr.predict(x_test)

# %%
# Evaluate the model performance of the algorithm :
print('Accuarcy:' , metrics.accuracy_score(y_test,y_pred) )
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Accuarcy: 0.7662337662337663
# [[82 17]
#  [19 36]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82        99
#            1       0.68      0.65      0.67        55
#
#     accuracy                           0.77       154
#    macro avg       0.75      0.74      0.74       154
# weighted avg       0.76      0.77      0.77       154

# %%
# 0 , 1 MEAN THE CLASSES
